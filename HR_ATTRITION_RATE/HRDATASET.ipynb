# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading the data

# %%
df=pd.read_csv('HRdataset.csv')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# ## Data cleaning

# %%
#Finding nullvalues
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# #### There are no missing values in the dataset.

# %%
#Finding duplicate values
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### There are no duplicate values

# %% [markdown]
# ##  Descriptive Statistics

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender',
#        'JobRole', 'MaritalStatus', 'Over18', 'OverTime'],
#       dtype='object')

# %%
df.select_dtypes(exclude='object').columns
# Out:
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome',
#        'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
cat=[]
num=[]
for i in df.columns:
    if df[i].dtype=='object':
        cat.append(i)
    else:
        num.append(i)
print('Categorical columns--',cat)
print()
print('Numerical columns--',num)
# Out:
# Categorical columns-- ['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime']
#
# Numerical columns-- ['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %%
for i in cat:
    print('****************',i,'******************')
    print(df[i].value_counts())
# Out:
# **************** Attrition ******************
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64
# **************** BusinessTravel ******************
# BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64
# **************** Department ******************
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64
# **************** EducationField ******************
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64
# **************** Gender ******************
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64
# **************** JobRole ******************
# JobRole
# Sales Executive              326
# Research Scientist           292
# ...

# %% [markdown]
# ## Data Visualization

# %%
sns.histplot(df['Age'],kde=True,color='blue')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.countplot(data=df,x=df['JobSatisfaction'],hue=df['Gender'],legend=True,palette='coolwarm')
# Out:
# <Axes: xlabel='JobSatisfaction', ylabel='count'>

# %%
sns.histplot(data=df,x=df['MonthlyIncome'],kde=True)
# Out:
# <Axes: xlabel='MonthlyIncome', ylabel='Count'>

# %%
sns.countplot(data=df,x=df['PerformanceRating'],hue=df['Gender'])
# Out:
# <Axes: xlabel='PerformanceRating', ylabel='count'>

# %%
sns.countplot(data=df,x=df['WorkLifeBalance'],hue=df['Gender'])
# Out:
# <Axes: xlabel='WorkLifeBalance', ylabel='count'>

# %%
sns.countplot(data=df,x=df["Attrition"],hue=df["Gender"],legend=True,palette='Set2')
# Out:
# <Axes: xlabel='Attrition', ylabel='count'>

# %%
sns.countplot(data=df,x=df["BusinessTravel"],hue=df['BusinessTravel'],legend=False,palette='Set2')
# Out:
# <Axes: xlabel='BusinessTravel', ylabel='count'>

# %%
sns.countplot(data=df,x=df["Department"],hue=df['Department'],legend=False,palette='Set2')
# Out:
# <Axes: xlabel='Department', ylabel='count'>

# %%
import plotly.express as px
px.pie(data_frame=df,values=df['EducationField'].value_counts().values,names=df['EducationField'].value_counts().index)

# %%
px.pie(data_frame=df,values=df['JobRole'].value_counts().values,names=df['JobRole'].value_counts().index)

# %%
sns.countplot(data=df,x=df['Gender'],hue=df['Gender'],palette='coolwarm')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
#Overtime,Age and Marital Status
plt.figure(figsize=(10,6))
sns.swarmplot(data=df,x=df['OverTime'],y=df['Age'],hue=df["MaritalStatus"])
# Out:
# <Axes: xlabel='OverTime', ylabel='Age'>

# %% [markdown]
# #### General Insights:
# Younger employees (20–30 years old), especially single ones, tend to work overtime more often than older employees.
# Older employees (above 50 years old) are more likely to avoid working overtime, regardless of their marital status.
# Marital status does play a role, with single employees showing a higher propensity to work overtime compared to married and divorced employees.

# %%
# Group by on basis of Jobrole with avg monthly salary
income_group=df.groupby('JobRole').agg(Average_salary=('MonthlyIncome','mean')).reset_index().sort_values(by='Average_salary',ascending=False)
income_group
# Out:
#                      JobRole  Average_salary
# 3                    Manager    17181.676471
# 5          Research Director    16033.550000
# 0  Healthcare Representative     7528.763359
# 4     Manufacturing Director     7295.137931
# 7            Sales Executive     6924.279141
# 1            Human Resources     4235.750000
# 6         Research Scientist     3239.972603
# 2      Laboratory Technician     3237.169884
# 8       Sales Representative     2626.000000

# %%
sns.barplot(x=income_group['JobRole'],y=income_group['Average_salary'],palette='Spectral')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Manager'),
#   Text(1, 0, 'Research Director'),
#   Text(2, 0, 'Healthcare Representative'),
#   Text(3, 0, 'Manufacturing Director'),
#   Text(4, 0, 'Sales Executive'),
#   Text(5, 0, 'Human Resources'),
#   Text(6, 0, 'Research Scientist'),
#   Text(7, 0, 'Laboratory Technician'),
#   Text(8, 0, 'Sales Representative')])

# %% [markdown]
# #### General Insights:
# Managers are having the highest average_salary while sales representatives are having the lowest.

# %%
# With respect to deparments what is the maximum hike in salary and their max_rating
df.groupby("Department").agg(Max_salary_Hike=("PercentSalaryHike","max"),Max_Rating=('PerformanceRating',"max"))
# Out:
#                         Max_salary_Hike  Max_Rating
# Department
# Human Resources                      23           4
# Research & Development               25           4
# Sales                                25           4

# %%
#Counting the attrition from different departments
Attrition_dept=df[df["Attrition"]=='Yes']["Department"].value_counts()/df["Department"].value_counts()*100
AD=pd.DataFrame(Attrition_dept)
AD
# Out:
#                             count
# Department
# Research & Development  13.839750
# Sales                   20.627803
# Human Resources         19.047619

# %%
px.pie(data_frame=AD,values=AD["count"],names=AD.index,title="Attrition Rate by Department")

# %% [markdown]
# ### Finding the outliers

# %%
num
# Out:
# ['Age',
#  'DailyRate',
#  'DistanceFromHome',
#  'Education',
#  'EmployeeCount',
#  'EmployeeNumber',
#  'EnvironmentSatisfaction',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobSatisfaction',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StandardHours',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
sns.boxplot(x=df["WorkLifeBalance"],y=df["Age"])
# Out:
# <Axes: xlabel='WorkLifeBalance', ylabel='Age'>

# %%
plt.figure(figsize=(14,10))
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# There is a strong correlation between the following variable pairs:
# Job Level and Monthly Income,
# Job Level and Total Working Years,
# Percent Salary Hike and Performance Rating,
# Years at Company and Years in Current Role

# %%
df=df.drop("JobLevel",axis=1)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
x=df.drop(["Attrition","EmployeeNumber","EmployeeCount","StandardHours","Over18"],axis=1)
y=df["Attrition"]

# %%
x
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 0      41      Travel_Rarely       1102                   Sales
# 1      49  Travel_Frequently        279  Research & Development
# 2      37      Travel_Rarely       1373  Research & Development
# 3      33  Travel_Frequently       1392  Research & Development
# 4      27      Travel_Rarely        591  Research & Development
# ...   ...                ...        ...                     ...
# 1465   36  Travel_Frequently        884  Research & Development
# 1466   39      Travel_Rarely        613  Research & Development
# 1467   27      Travel_Rarely        155  Research & Development
# 1468   49  Travel_Frequently       1023                   Sales
# 1469   34      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                    1          2  Life Sciences                        2
# ...

# %%
y
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3        No
# 4        No
#        ...
# 1465     No
# 1466     No
# 1467     No
# 1468     No
# 1469     No
# Name: Attrition, Length: 1470, dtype: object

# %%
y1=y.map({"Yes":'1',"No":"0"})

# %%
y1
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 1470, dtype: object

# %%
x.columns
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_curve,roc_auc_score

# %%
categorical_features=['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'OverTime']
numerical_features=['Age', 'DailyRate', 'DistanceFromHome', 'Education','EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %%
preprocessor=ColumnTransformer(transformers=[("num",StandardScaler(),numerical_features),
                                            ("cat",OneHotEncoder(),categorical_features)])

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('num', StandardScaler(),
#                                  ['Age', 'DailyRate', 'DistanceFromHome',
#                                   'Education', 'EnvironmentSatisfaction',
#                                   'HourlyRate', 'JobInvolvement',
#                                   'JobSatisfaction', 'MonthlyIncome',
#                                   'MonthlyRate', 'NumCompaniesWorked',
#                                   'PercentSalaryHike', 'PerformanceRating',
#                                   'RelationshipSatisfaction',
#                                   'StockOptionLevel', 'TotalWorkingYears',
#                                   'TrainingTimesLastYear', 'WorkLifeBalance',
#                                   'YearsAtCompany', 'YearsInCurrentRole',
#                                   'YearsSinceLastPromotion',
#                                   'YearsWithCurrManager']),
#                                 ('cat', OneHotEncoder(),
# ...

# %%
pipeline=Pipeline(steps=[('preprocessor',preprocessor),('regressor',LogisticRegression())])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y1,test_size=0.2,random_state=42)

# %%
pipeline.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['Age', 'DailyRate',
#                                                    'DistanceFromHome',
#                                                    'Education',
#                                                    'EnvironmentSatisfaction',
#                                                    'HourlyRate',
#                                                    'JobInvolvement',
#                                                    'JobSatisfaction',
#                                                    'MonthlyIncome',
#                                                    'MonthlyRate',
#                                                    'NumCompaniesWorked',
#                                                    'PercentSalaryHike',
#                                                    'PerformanceRating',
# ...

# %%
y_pred=pipeline.predict(x_test)

# %%
test_accuracy=accuracy_score(y_test,y_pred)

# %%
test_accuracy
# Out:
# 0.8877551020408163

# %%
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[244,  11],
#        [ 22,  17]], dtype=int64)

# %%
sns.heatmap(cm,annot=True,cmap="Blues",fmt='d')
plt.xlabel("predicted")
plt.ylabel("actual")
plt.title("Confusion Matrix(Test)")
# Out:
# Text(0.5, 1.0, 'Confusion Matrix(Test)')

# %%
tn,fp,fn,tp=confusion_matrix(y_test,y_pred).ravel()

# %%
#Recall
recall=tp/tp+fn
recall
# Out:
# 23.0

# %%
#Precision
precision=tp/(tp+fp)
precision
# Out:
# 0.6071428571428571

# %%
#f1_score
f1_score=(2*(precision*recall))/(precision+recall)
f1_score
# Out:
# 1.1830559757942511
